# %%
import numpy as np
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
from numpy.random import randn

# %%
labels=['a','b','c']
my_list=[10.,20,30]
arr=np.array(my_list)
d={x:y for x,y in zip(labels,my_list)}

# %%
print(d)
# Out:
# {'a': 10.0, 'b': 20, 'c': 30}

# %%
pd.Series(my_list)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# dtype: float64

# %%
pd.Series(arr)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# dtype: float64

# %%
pd.Series(arr,labels)
# Out:
# a    10.0
# b    20.0
# c    30.0
# dtype: float64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10.0
# b    20.0
# c    30.0
# dtype: float64

# %%
pd.Series(labels,my_list)
# Out:
# 10.0    a
# 20.0    b
# 30.0    c
# dtype: object

# %%
pd.Series(d)
# Out:
# a    10.0
# b    20.0
# c    30.0
# dtype: float64

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1=pd.Series([1,55,9,4],index=['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA         1
# Germany    55
# USSR        9
# Japan       4
# dtype: int64

# %%
ser2=pd.Series([1,2,5,4],index=['USA','Germany','italy','Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# italy      5
# Japan      4
# dtype: int64

# %%
ser1['USSR']
# Out:
# 9

# %%
ser3=ser1+ser2

# %%
ser3
# Out:
# Germany    57.0
# Japan       8.0
# USA         2.0
# USSR        NaN
# italy       NaN
# dtype: float64

# %% [markdown]
# # 2 Dataframes

# %%
datas=[['Alex',10],['Bob',12],['Clarke',13]]
df=pd.DataFrame(datas,columns=['Name','Age'],dtype=float)

# %%
df
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0

# %%
pd.DataFrame([[23,'Utensils'],[12,'Clothes'],[34,"Electronics"]],columns=['itemID',"itemType"])
# Out:
#    itemID     itemType
# 0      23     Utensils
# 1      12      Clothes
# 2      34  Electronics

# %%
data={'Name':['Tom','Jack','Steve','Ricky'],'Age':[23,34,45,56]}

# %%
df=pd.DataFrame(data,index=['rank1','rank2','rank3','rank4'])

# %%
df
# Out:
#         Name  Age
# rank1    Tom   23
# rank2   Jack   34
# rank3  Steve   45
# rank4  Ricky   56

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'Two':pd.Series([1,2,3,4],index=['a','b','c','d'])}

# %%
df=pd.DataFrame(d)

# %%
df.iloc[2]
# Out:
# one    3.0
# Two    3.0
# Name: c, dtype: float64

# %%
N=20
df=pd.DataFrame({
    'A':pd.date_range(start='2016-01-01',periods=N,freq='D'),
    'X':np.linspace(0,stop=N-1,num=N),
    'Y':np.random.randn(N),
    'C':np.random.choice(['low','Medium','High'],N).tolist(),
    'D':np.random.normal(100,10,size=(N)).tolist()
})
df
# Out:
#             A     X         Y       C           D
# 0  2016-01-01   0.0 -0.435684     low  111.673747
# 1  2016-01-02   1.0  1.332861  Medium   89.829455
# 2  2016-01-03   2.0  1.072071    High  101.706978
# 3  2016-01-04   3.0  0.662833  Medium  101.240577
# 4  2016-01-05   4.0 -0.160884  Medium   89.635848
# 5  2016-01-06   5.0  1.671056  Medium   88.201028
# 6  2016-01-07   6.0 -0.958289     low  105.299678
# 7  2016-01-08   7.0 -0.320837  Medium  103.639009
# 8  2016-01-09   8.0 -0.713263    High  111.863444
# 9  2016-01-10   9.0  0.582793    High  102.535616
# 10 2016-01-11  10.0 -0.773932     low  106.312564
# 11 2016-01-12  11.0  0.778914     low   93.090970
# 12 2016-01-13  12.0  0.226762  Medium   81.136401
# 13 2016-01-14  13.0 -0.573729    High  102.008487
# 14 2016-01-15  14.0 -0.554030    High  111.734911
# 15 2016-01-16  15.0 -1.441838    High  122.788356
# 16 2016-01-17  16.0 -1.423064     low  107.774310
# 17 2016-01-18  17.0 -1.169767  Medium   77.365446
# ...

# %% [markdown]
# # working with functions

# %%
np.random.seed(55)
df=pd.DataFrame(randn(5,4),index="A B C D E".split(),columns="w x y z".split())

# %%
df
# Out:
#           w         x         y         z
# A -1.623731 -0.101784 -1.809791  0.262654
# B  0.259953 -0.381086 -0.002290  0.341615
# C  0.897572 -0.361100  1.656445 -1.189009
# D  1.666429 -2.003439 -0.477873  1.368799
# E  0.258169  0.702352  0.888382  0.722220

# %%
x=np.random.normal(loc=100,scale=10,size=100)

# %%
x=np.random.normal(loc=100,scale=10,size=100)
dt=pd.DataFrame({'Values':x})
dt.plot.hist()

# %% [markdown]
# # Sql syntax

# %%
df
# Out:
#           w         x         y         z
# A -1.623731 -0.101784 -1.809791  0.262654
# B  0.259953 -0.381086 -0.002290  0.341615
# C  0.897572 -0.361100  1.656445 -1.189009
# D  1.666429 -2.003439 -0.477873  1.368799
# E  0.258169  0.702352  0.888382  0.722220

# %%
df['w']
# Out:
# A   -1.623731
# B    0.259953
# C    0.897572
# D    1.666429
# E    0.258169
# Name: w, dtype: float64

# %%
type(df['w'])
# Out:
# pandas.core.series.Series

# %%
df['new']=df['w']+df['z']

# %%
df
# Out:
#           w         x         y         z       new
# A -1.623731 -0.101784 -1.809791  0.262654 -1.361077
# B  0.259953 -0.381086 -0.002290  0.341615  0.601568
# C  0.897572 -0.361100  1.656445 -1.189009 -0.291437
# D  1.666429 -2.003439 -0.477873  1.368799  3.035227
# E  0.258169  0.702352  0.888382  0.722220  0.980388

# %%
df.drop('new',axis=1,inplace=True)

# %%
df.w
# Out:
# A   -1.623731
# B    0.259953
# C    0.897572
# D    1.666429
# E    0.258169
# Name: w, dtype: float64

# %%
df
# Out:
#           w         x         y         z
# A -1.623731 -0.101784 -1.809791  0.262654
# B  0.259953 -0.381086 -0.002290  0.341615
# C  0.897572 -0.361100  1.656445 -1.189009
# D  1.666429 -2.003439 -0.477873  1.368799
# E  0.258169  0.702352  0.888382  0.722220

# %%
df.iloc[2]
# Out:
# w    0.897572
# x   -0.361100
# y    1.656445
# z   -1.189009
# Name: C, dtype: float64

# %%
df.loc['B','x']
# Out:
# -0.3810863829200849

# %%
df.loc[['A','B'],['w','y']]
# Out:
#           w         y
# A -1.623731 -1.809791
# B  0.259953 -0.002290

# %%
df[df['w']>0][['y','x']]
# Out:
#           y         x
# B -0.002290 -0.381086
# C  1.656445 -0.361100
# D -0.477873 -2.003439
# E  0.888382  0.702352

# %%
df[(df['w']>0)&(df['y']<0.5)]
# Out:
#           w         x         y         z
# B  0.259953 -0.381086 -0.002290  0.341615
# D  1.666429 -2.003439 -0.477873  1.368799

# %%
df.reset_index()
# Out:
#   index         w         x         y         z
# 0     A -1.623731 -0.101784 -1.809791  0.262654
# 1     B  0.259953 -0.381086 -0.002290  0.341615
# 2     C  0.897572 -0.361100  1.656445 -1.189009
# 3     D  1.666429 -2.003439 -0.477873  1.368799
# 4     E  0.258169  0.702352  0.888382  0.722220

# %%
newind='CA NY WY OR CO'.split()
df['States']=newind
df
# Out:
#           w         x         y         z States
# A -1.623731 -0.101784 -1.809791  0.262654     CA
# B  0.259953 -0.381086 -0.002290  0.341615     NY
# C  0.897572 -0.361100  1.656445 -1.189009     WY
# D  1.666429 -2.003439 -0.477873  1.368799     OR
# E  0.258169  0.702352  0.888382  0.722220     CO

# %%
df.set_index('States')
# Out:
#                w         x         y         z
# States
# CA     -1.623731 -0.101784 -1.809791  0.262654
# NY      0.259953 -0.381086 -0.002290  0.341615
# WY      0.897572 -0.361100  1.656445 -1.189009
# OR      1.666429 -2.003439 -0.477873  1.368799
# CO      0.258169  0.702352  0.888382  0.722220

# %% [markdown]
# # Another angle at Dataframes

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
